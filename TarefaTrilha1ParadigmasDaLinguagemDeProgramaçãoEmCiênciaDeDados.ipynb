# %% [markdown]
# <a href="https://colab.research.google.com/github/Negrair/cienciadedadosmackenzie/blob/main/TarefaTrilha1ParadigmasDaLinguagemDePrograma%C3%A7%C3%A3oEmCi%C3%AAnciaDeDados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TEXTO: Discurso Steve Jobs Stanford Commencement Address
#
# Escolhi este texto por ser um grande fã de toda a história do Steve Jobs, um dos maiores gênios da história moderna.
# Nesse discurso ele conta alguns fatos sobre a sua vida e como algumas decisões pessoais ao longo de sua vida tiveram grande #importância na sua trajetória profissional.

# %% [markdown]
# Aquisição dos Dados:

# %%
import urllib.request

texto = []

for line in urllib.request.urlopen('https://raw.githubusercontent.com/Negrair/cienciadedadosmackenzie/main/steve'): 
    texto.append(line.decode('utf-8'))

    
for i in range(len(texto)):
    texto[i] = texto[i].lower()
    texto[i] = texto[i].replace('\n','')
    texto[i] = texto[i].replace('.','')
    texto[i] = texto[i].replace(',','')
    texto[i] = texto[i].replace('(','')
    texto[i] = texto[i].replace(')','')
    texto[i] = texto[i].replace('?','')
    texto[i] = texto[i].replace('\'','')

# %% [markdown]
# Construção do Dicionário:

# %%
mydict = {} 

for line in texto:
    line = line.lower()
    words = line.split()
    for word in words:
        if word not in mydict.keys():
            mydict[word] = 1
        else:
            mydict[word] =  mydict[word] + 1
print(mydict)
# Out:
# {'estou': 4, 'honrado': 1, 'por': 24, 'estar': 2, 'aqui': 1, 'com': 10, 'vocês': 10, 'em': 24, 'sua': 7, 'formatura': 3, 'uma': 28, 'das': 3, 'melhores': 2, 'universidades': 1, 'do': 20, 'mundo': 2, 'eu': 29, 'mesmo': 5, 'não': 28, 'concluí': 1, 'a': 55, 'faculdade': 4, 'para': 17, 'ser': 5, 'franco': 1, 'jamais': 2, 'havia': 9, 'estado': 1, 'tão': 3, 'perto': 2, 'de': 62, 'até': 1, 'hoje': 4, 'pretendo': 1, 'lhes': 3, 'contar': 1, 'três': 3, 'histórias': 1, 'sobre': 8, 'minha': 18, 'vida': 18, 'agora': 2, 'só': 6, 'isso': 15, 'nada': 3, 'demais': 1, 'apenas': 1, 'históriasa': 1, 'primeira': 1, 'é': 24, 'ligar': 1, 'os': 8, 'pontos': 3, 'larguei': 1, 'o': 59, 'reed': 2, 'college': 2, 'depois': 1, 'um': 21, 'semestre': 1, 'mas': 15, 'continuei': 1, 'assistindo': 1, 'algumas': 3, 'aulas': 3, 'mais': 11, '18': 1, 'meses': 6, 'antes': 5, 'desistir': 2, 'vez': 1, 'que': 74, 'desisti': 1, 'tudo': 10, 'começou': 1, 'nascer': 1, 'mãe': 3, 'biológica': 2, 'era': 18, 'jovem': 2, 'e': 67, 'casada;': 1, 'estava': 7, 'fazendo': 2, 'doutorado': 1, 'decidiu': 1, 'me': 13, 'ofereceria': 1, 'adoção': 2, 'ela': 2, 'determinada': 1, 'encontrar': 2, 'pais': 4, 'adotivos': 1, 'tivessem': 1, 'educação': 1, 'superior': 2, 'quando': 10, 'nasci': 1, 'as': 10, 'coisas': 3, 'estavam': 2, 'armadas': 1, 'forma': 3, 'fosse': 3, 'adotado': 1, 'advogado': 1, 'mulher': 3, 'eles': 3, 'terminaram': 1, 'decidir': 1, 'preferiam': 1, 'menina': 1, 'assim': 3, 'meus': 5, 'lista': 1, 'espera': 1, 'receberam': 1, 'telefonema': 1, 'plena': 1, 'madrugada': 1, '¿"temos': 1, 'menino': 1, 'inesperado': 1, 'aqui;': 1, 'querem"': 1, 'dois': 1, 'responderam': 1, '"claro': 1, 'sim"': 1, 'descobriu': 1, 'tarde': 5, 'adotiva': 1, 'tinha': 9, 'diploma': 2, 'universitário': 1, 'meu': 4, 'pai': 1, 'nem': 4, 'segundo': 1, 'grau': 1, 'se': 16, 'recusou': 1, 'assinar': 1, 'documento': 1, 'final': 4, 'durante': 1, 'alguns': 3, 'mudou': 3, 'idéia': 2, 'prometeram': 1, 'faria': 1, 'curso': 5, '17': 2, 'anos': 14, 'foi': 10, 'fiz': 2, 'ingenuamente': 1, 'escolhi': 1, 'quase': 3, 'cara': 1, 'quanto': 3, 'stanford': 1, 'todas': 1, 'economias': 2, 'dos': 8, 'eram': 2, 'ricos': 1, 'foram': 2, 'gastas': 1, 'pagar': 1, 'estudos': 1, 'passados': 1, 'seis': 2, 'via': 1, 'valor': 1, 'aprendia': 1, 'sabia': 3, 'queria': 1, 'fazer': 4, 'da': 13, 'entendia': 1, 'como': 7, 'poderia': 2, 'ajudar': 2, 'lá': 2, 'gastando': 1, 'inteira': 1, 'decidi': 3, 'confiando': 1, 'ajeitariam': 1, 'admito': 1, 'fiquei': 2, 'assustado': 1, 'retrospecto': 3, 'minhas': 1, 'decisões': 1, 'bastou': 1, 'largar': 1, 'parasse': 1, 'assistir': 2, 'às': 4, 'chatas': 1, 'assistisse': 1, 'interessavam': 1, 'romântico': 1, 'aluno': 1, 'portanto': 1, 'quarto;': 1, 'dormia': 1, 'no': 6, 'chão': 1, 'quartos': 1, 'colegas;': 1, 'vendia': 1, 'garrafas': 1, 'vazias': 1, 'refrigerante': 1, 'conseguir': 1, 'dinheiro;': 1, 'caminhava': 1, '11': 1, 'quilômetros': 1, 'cada': 2, 'noite': 2, 'domingo': 1, 'porque': 7, 'templo': 1, 'hare': 1, 'krishna': 1, 'oferecia': 1, 'refeição': 1, 'gratuita': 1, 'adorava': 1, 'então': 2, 'boa': 1, 'parte': 2, 'daquilo': 1, 'tropecei': 1, 'seguindo': 1, 'curiosidade': 1, 'intuição': 1, 'provou': 1, 'valioso': 1, 'vou': 1, 'oferecer': 1, 'exemplo': 1, 'na': 10, 'época': 2, 'talvez': 3, 'tivesse': 1, 'melhor': 5, 'caligrafia': 2, 'país': 1, 'todos': 3, 'cartazes': 1, 'etiquetas': 1, 'campus': 1, 'escritos': 1, 'letra': 1, 'belíssima': 1, 'normais': 1, 'aprender': 1, 'aprendi': 1, 'tipos': 1, 'sem': 5, 'serifa': 1, 'variações': 1, 'espaço': 1, 'entre': 1, 'diferentes': 1, 'combinação': 1, 'letras': 1, 'características': 1, 'definem': 1, 'qualidade': 1, 'tipografia': 2, 'belo': 1, 'histórico': 1, 'sutilmente': 1, 'artístico': 1, 'maneira': 4, 'inacessível': 1, 'à': 4, 'ciência': 1, 'fascinadomas': 1, 'esperança': 1, 'aplicar': 1, 'aquilo': 5, 'entanto': 1, 'dez': 3, 'estávamos': 2, 'projetando': 1, 'primeiro': 3, 'macintosh': 2, 'lembrei': 1, 'projeto': 2, 'mac': 3, 'incluía': 1, 'esse': 2, 'aprendizado': 1, ' ...

# %% [markdown]
# Exibição dos Resultados:

# %%
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

df = pd.DataFrame(mydict.items(),  columns=['word', 'count']).sort_values('count',ascending=False)
df = df[df['count'] > 4] # somente termos com mais de 4 ocorrências
# df = df.iloc[ np.int(len(df)/2) - 10 : np.int(len(df)/2) + 10 ] # para livros ou textos com muitos termos limita a um número mínimo de termos

plt.figure(figsize=(24,10))
mpl.style.use(['seaborn'])
sns.barplot(x=df.word,y=df['count'])
plt.xticks(rotation=90) 

plt.show()

# %% [markdown]
# Apos a leitura do gráfico e excluindo as preposições é possível observar as seguintes palavras que mais se repetem no texto:
# vida, anos, quando, voces, havia, estava, meses, morte, apple, muito, curso, tarde.
